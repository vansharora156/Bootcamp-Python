# %% [markdown]
# # Handling Null Values :-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\DELL\Downloads\titanic_train.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# isnull() :-

# %% [markdown]
# This method returns a DataFrame of the same shape as the input, where each element is True if it's a null value and False otherwise. It's useful for pinpointing null values within the dataset.

# %%
df.isnull().sum()  #gives sum of null values in a specific column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# info() :-

# %% [markdown]
# The info() method provides a concise summary of the DataFrame, including the count of non-null values for each column. It's a quick way to assess the presence of null values and the overall data structure.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# fillna(): Fills null values with a specified value or method.

# %%
df2 = df["Embarked"].fillna(value = "S") 
df2.head()

df2.isnull().sum()
# Check the number of null values in the entire DataFrame df2
print(df2.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# ONE OF THE WAY TO REMOVE NULL VALUES ARE USING PAD WHICH MEANS FILLING IT WITH PREVIOUS ROWS DATA,BFIll and many more down

# %%
df3 = df.fillna(method='pad')
df3 #the output will have the Nan value replaced with the value of the row above it.
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9860\3471833360.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3 = df.fillna(method='pad')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# Let's change the null value with the value of the next row
df4 = df.fillna(method='bfill')
df4
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9860\1071079353.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4 = df.fillna(method='bfill')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# Filling null values with the previous value but column wise
df5 = df.fillna(method='pad',axis=1)
df5
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9860\1035411179.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df5 = df.fillna(method='pad',axis=1)
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex     Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0     1
# 2                               Heikkinen, Miss. Laina  female    26.0     0
# ...

# %%
df6 = df.fillna({ 'Cabin': 'Unknown'})
print(df6.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  Unknown        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  Unknown        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 8)) 

# Histogram
plt.subplot(1, 2,1 )
sns.histplot(df['Fare'], kde=True)
plt.title('Histogram of Fare')
plt.xlim(0, 100)

# Density Plot (KDE)
plt.subplot(1, 2, 2)
sns.kdeplot(df['Fare'], shade=True)
plt.title('Density Plot of Fare')
plt.xlim(0, 100)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9860\1439232176.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Fare'], shade=True)

# %%
median_fare = df['Fare'].median()
print("Median Fare:", median_fare)
# Out:
# Median Fare: 14.4542

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df['Fare_filled'] = df['Fare'].fillna(df['Fare'].median())
fig, axs = plt.subplots(1, 2, figsize=(16, 6), sharey=True)  

sns.histplot(df['Fare'], kde=True, color='lightblue', bins=40, ax=axs[0])
axs[0].set_title("Original Data Distribution")
axs[0].set_xlabel("Fare")
axs[0].set_ylabel("Frequency")
axs[0].set_xlim(0, 100)  

sns.histplot(df['Fare_filled'], kde=True, color='green', bins=40, ax=axs[1])
axs[1].set_title("Data Distribution after Filling with Median")
axs[1].set_xlabel("Fare")
axs[1].set_xlim(0, 100) 

plt.tight_layout()
plt.show()

# %% [markdown]
# dropna():

# %% [markdown]
# The dropna() method in pandas removes rows or columns with null values from a DataFrame. Parameters like subset, thresh, how, and axis offer customization:

# %%
df10 = df.dropna()
df10
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# how='any' means if any row has a null values it is removed (default)
df11 =df.dropna(how='any')
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# how='all' means it drop the row that have all nul values
df12 = df.dropna(how='all')
df12
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# What if you want to drop column with null values, there is a parameter for it
df13 = df.dropna(axis=1)
df13
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df14 = df.dropna(subset=['Cabin', 'Embarked'])
df14.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
# Drop rows with at least a certain number of non-null values
df15 =  df.dropna(thresh=5)
df15
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = r'C:\Users\DELL\Downloads\titanic_train.csv'
df = pd.read_csv(file_path)
df_interpolated = df.copy()
df_interpolated['Fare_interpolated'] = df['Fare'].interpolate(method='linear')
plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
sns.histplot(df['Fare'], kde=True, color='lightblue', bins=40)
plt.title('Original Data Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.xlim(0, 300)  

# Interpolated data distribution
plt.subplot(1, 2, 2)
sns.histplot(df_interpolated['Fare_interpolated'], kde=True, color='green', bins=40)
plt.title('Data Distribution after Interpolation')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.xlim(0, 300)  

plt.tight_layout()
plt.show()
